# %%
import numpy
import matplotlib.pyplot as plt
import BeautifulSoup

import time

# %%
soup = BeautifulSoup.BeautifulSoup(open('wall.htm'))
allAttrs = [tag.string for tag in soup.findAll('div')]

# %%
dates = []
for string in allAttrs:
        try :
                dates.append(str(str(string).strip('u')).split())
        except TypeError :
                print string

#dateList = numpy.asarray(dates, dtype=int)

print len(dates)
# Out:
# 3613

# %%
dayList = []
dateList = []
monthList = []
yearList = []

for string in dates[3:]:
        try:
                dayList.append(string[0])
                dateList.append(string[2])
                monthList.append(string[1])
                yearList.append(string[3])
        except IndexError:
                print string
# Out:
# ['Stalked', 'you!', '^_^']
# ['http://idlewords.com/talks/what_happens_next_will_amaze_you.htm']
# ['half-a-century', 'of', 'posts...']
# ['10', 'more.']
# ['omg!', ':o']
# [':&#039;(', ':&#039;(']
# ['Created', 'with', 'facebook.com/celebratepride']
# ['sooo', 'so', 'beautiful!']
# ['yeowza!', ':D']
# ['*_*']
# ['simply', 'breathtaking!']
# ['damn', ':O']
# ['10', 'TB!']
# ['http://www.atlasobscura.com/places/the-great-green-wall-of-africa']
# ['damn']
# ['ohmygodohmygodohmygod']
# ['so', 'much', 'awesomeness!!!']
# ['I', 'am', 'Batman!']
# ['beautifully', 'written']
# ['goosebumps', ':D...']
# ['epic!!!', ':D...']
# ['lolol!!']
# ['lolol!', ':D...']
# ['awwwesome!!!', ':D...']
# [':/']
# ['x\xef\xbf\xbd\xef\xbf\xbdi\xef\xbf\xbdQRR`\xef\xbf\xbd\xef\xbf\xbd_\xef\xbf\xbd\xef\xbf\xbdQ\xef\xbf\xbdS\xef\xbf\xbd_TZ\xef\xbf\xbd\xef\xbf\xbd\xef\xbf\xbd\xef\xbf\xbd\xef\xbf\xbd\xef\xbf\xbd^\\\xef\xbf\xbd_\xef\xbf\xbd\xef\xbf\xbd\xef\xbf\xbd\xef\xbf\xbd\xef\xbf\xbd\xc3\x85EAzfIFi\xef\xbf\xbd^f\xef\xbf\xbd&gt;\xef\xbf\xbd*\x16\x18J']
# ['lolol!', ':D...']
# ['LOLOL!!!', 'X-D...']
# ['woah!']
# ['Yo!']
# ['adrenaline', 'boost!', ':D...']
# ['Happy', 'Birthday...!!!']
# ['happie', 'bdayy', ':))']
# ['Happy', 'birthday!', ':D']
# ['Happy', 'Birthday!', ':)']
# ['happy', 'birthday', 'ra...']
# ['happy', 'b`day', 'dude...']
# ['happy', 'bday..']
# ['happy', 'birthday!']
# ['Happy', 'Birthday', ':)']
# ['Happy', 'Birthday', 'man!']
# ['Happy', 'birthday!!', ':D']
# ['happy', 'bday', ':)']
# ['Happy', 'Birthday']
# ['Happy', 'Birthday!']
# ['happy', 'birthday!!!']
# ['Happy', 'Birthday!!:)']
# ['Happy', 'birthday', 'man!']
# ['Happy', 'Birthday!!']
# ['Happy', 'Birthday', 'dude']
# ['happy', 'birthday', ':)']
# ['happy', 'birthday!!!']
# ['Happy', 'Birthday', 'Drlz...']
# ['happie', 'b.day', 'ra']
# ['Happy', 'Birthday!!']
# ['Happy', 'Birthday!', ':)']
# ['Happy', 'birthday', 'man!!']
# ['Hapy', 'b&#039;day']
# ['Happy', 'Bday']
# ['Woah!']
# ['Sad', ':(']
# ['epic!!!', ':D...']
# ['http://blogs.nature.com/naturejobs/2011/10/04/major-survey-of-phd-students-in-europe-sheds-light-on-working-life']
# ['http://www.nytimes.com/2013/10/20/opinion/sunday/the-good-men-of-india.html?smid=fb-share&amp;_r=0', 'Because.']
# ['http://mrwgifs.com/excited-really-spongebob-reaction-gif/']
# ['hehehe', ':D...']
# ['Brilliant!']
# ['Ani', ':D...']
# ['lol!']
# ['well', 'said', 'sir!']
# [':&#039;D', 'LOL!']
# ['lol', ':D...']
# ['fffack!', ':O']
# ['Patel', ':D...']
# ['so', 'beautiful', ':&#039;)...']
# ['epic!', ':`D...']
# ['this']
# ['interesting...']
# ['sigh.', 'sigh...']
# ['zen', ':)']
# ['just', '2', 'steps!']
# ['epic', 'wonly!']
# ['albeit', 'late...']
# ['http://www.youtube.com/watch?v=fWNaR-rxAic', ':|']
# ['woww..']
# ['one', 'more', 'week...']
# ['epic!!!']
# ['week', '2!']
# ['namaskaram.', 'from', 'trivandrum.']
# ['LMAO!', 'EPIC!', ':D...']
# ['Come', 'back', ':&#039;(']
# ['Cat', 'guy', ':D']
# ['epic', ':D...']
# ['faaaaaack', ':D...']
# ['nnnnaaaaiiiiiccce']
# ['https://www.facebook.com/photo.php?fbid=493358167403274&amp;set=a.414754115263680.94958.414753515263740&amp;type=1&amp;theater']
# ['http://theoatmeal.com/comics/mantis_shrimp']
# ['LOL', ':D...']
# ['LOL!', ':D...']
# [':)']
# ['https://www.facebook.com/photo.php?fbid=321027264689755&amp;set=a.220052224787260.48006.220045591454590&amp;type=1&amp;theater']
# ['awesome!', ':D...']
# ['Red', 'Fort!!!']
# ['Red', 'Fort!!!']
# ['Red', 'Fort!!!']
# ['Red', 'Fort!!!']
# ['Red', 'Fort!!!']
# ['Red', 'Fort!!!']
# ['Red', 'Fort!!!']
# ['hehehehe...']
# ['EPIC!', ':D...']
# ['http://xkcd.com/482/', '&quot;mrowl!&quot;', 'hehehehe....']
# ['truly', 'inspiring', ':)...']
# ['http://www.project-syndicate.org/commentary/the-impact-of-educating-girls-on-economic-growth-in-developing-countries-by-shashi-tharoor#ID6mhceGDXxpurX4.99']
# ['happy', 'b&#039;day', 'buddy']
# ['Happy', 'Birthday', '!']
# ['hey,', 'happy', 'birthday!']
# ['Happy', 'bday', 'mama!']
# ['happy', 'b&#039;day', 'dude']
# ['Happy', 'birthday!', ':)']
# ['happy', 'birthday', '...:-)']
# ['happy', 'b&#039;day...']
# ['happpyy', 'birthdAYYYY...!!!', ':D']
# ['happy', 'birthday', 'ra']
# ['Happy', 'b&#039;day', 'man..:)']
# ['Happy', 'birthday', ':)']
# ['Happy', 'Birthday!!!']
# ['Happy', 'birthday!']
# ['happy', 'birthday', 'macha']
# ['happy', 'b&#039;day!!']
# ['happy', 'birthday', 'ra...!!']
# ['Happy', 'Bday..enjoy!!']
# ['Happy', 'Birthday!', ':)']
# ['Happy', 'bday', 'man!']
# ['happy', 'b&#039;dy', 'mams...']
# ['Hbd', '!', ':-)']
# ['Happy', 'Birthday', 'Doodh']
# ['Happy', 'bday....!!!']
# ['happy', 'bday', 'drlz...']
# ['Happy', 'Birthday!!']
# ['happy', 'birthday!!!!']
# ['happy', 'birthday', ':)']
# ['happy', 'birthday!!!']
# ['Happy', 'Birthday!!!!']
# ['Happy', 'B&#039;bday', 'da....!!!']
# ['Happy', 'Birthday', ':)']
# ['Happy', 'Birthday', 'da!']
# ['Happy', 'birthday!']
# ['Happy', 'Birthday!!!']
# ['Happy', 'birthday', 'bey!']
# ['Happy', 'Birthday', ':o)']
# ['www.thehindu.com/opinion/op-ed/the-great-number-fetish/article4345243.ece']
# ['awesome', ':D...']
# ['http://www.engadget.com/2012/09/02/stanford-wireless-power-implant/', '-', 'awesome!']
# ['awesome', ':D...']
# ['None']
# ['None']
# ['no', 'description', 'required.']
# [':)']
# ['blag', 'updated', ':d...']
# ['epic!', ':O', '...']
# ['nananananananananananana', ':D']
# [':O', 'awesome...']
# ['LOL', 'awesome', ':D...']
# ['http://www.indooratlas.com/', '-', 'awesome!']
# ['LOL', 'dude', ':D...']
# ['epic!', ':D', '...']
# ['None']
# ['epic', ':)', '....']
# ['controversial', 'but', 'interesting...']
# ['.\\\\', '//']
# ['EPIC', '!', ':D...']
# ['awesome!', ':D']
# ['epic', ':D', '...']
# ['Finally!!!!!!!!!!!']
# ['epic', ':D', '...']
# ['My', 'bitches', '-&gt;']
# ['my', 'niggas', ':D....']
# ['epic', ':D', '...']
# ['epic', '\\m/...']
# ['epic!']
# ['respect', '\\m/', ':D...']
# ['simply', 'beautiful', ':)...']
# ['\\m/', '...']
# ['\\m/', '...']
# [':D', '...']
# ['ehh......', 'wassup', 'doc?']
# ['LOL', ':D...']
# ['http://rahulporuri.blogspot.in/']
# ['Happy', 'Birthday....Haffun..!!:)']
# ['Happy', 'Bday....!!!']
# ['hi...rahul....']
# ['happy', 'bday.']
# ['happy', 'bday', 'buddy!!!!!']
# ['happy', 'b&#039;day..!!!']
# ['happy', 'bday', 'dude!!']
# ['Happy', 'Birthday.....!!']
# ['Happy', 'Bday', ':)']
# ['happy', 'bday', 'raa....']
# ['Happy', 'birthday...!!!']
# ['happy', 'bday!!']
# ['happy', 'b&#039;day', 'yaar.....']
# ['happy', 'birthday', 'ra!!!\\']
# ['Happy', 'Birthday']
# ['happy', 'b&#039;day', ':)']
# ['happy', 'bday']
# ['happy', 'birthday', ':)']
# ['happy', 'birthday', 'ra........']
# ['Happy', 'B&#039;day', 'ra!!...:)']
# ['Happy', 'Birthday!']
# ['Happy', 'birthday', '!']
# ['happy', 'birthday', ':)']
# ['happie', 'b&#039;day', 'macha!!']
# ['Happy', 'birthday']
# ['Happy', 'birthday', 'ra..!']
# ['happy', 'bday.....!']
# ['happy', 'bday', 'ra...']
# ['Birthday', 'wishes,', 'man!']
# ['happy', 'birthday']
# ['Happy', 'birthday', 'ra...']
# ['happy', 'b&#039;day', 'ra....']
# ['happy', 'bdy', 'mama']
# ['happy', 'b&#039;day', 'bro']
# ['Happy', 'Birthday', 'Rahul']
# ['happy', 'birthday', 'ra!!!!']
# ['HaPpY', 'bDaY...:)']
# ['Happy', 'Birthday!!!!!!!']
# ['happy', 'birthday.']
# ['Happy', 'Birthday', 'dude!']
# ['Happy', 'Birthday', 'man!']
# ['Happy', 'B&#039;day', 'ra']
# ['happy', 'bday', 'rahul']
# ['happy', 'b&#039;day']
# ['happy', 'birthday', 'mama']
# ['happy', 'bday', 'dude']
# ['happy', 'bday']
# ['\\m/', '...']
# ['None']
# ['hmm....', 'interesting....']
# [':)', '....']
# ['Jam&#039;s', 'Drams', '\\m/']
# ['LOL', '...']
# ['intelesting', '.....']
# ['aaaaaaaawesome', ':O........']
# ['LOL', ':D....']
# [':D', 'LOL', ',...']
# ['awesome', ':D....']
# ['WTF', '!!!']
# ['batman', '!!!!']
# ['browsers', ':D', '....']
# ['finally,']
# ['super-frigging-awesomeness', ':D...']
# ['Why', 'bunked', 'lab?']
# ['None']
# [':O', 'awesome', '...']
# [':D', '...']
# [':o', '...']
# [':D', '..']
# ['http://www.npr.org/2011/08/17/139681851/scientists-crack-the-physics-of-coffee-rings?ps=cprs']
# ['http://rahulporuri.blogspot.com/']
# ['LAWL', ':D']
# ['http://www.20thingsilearned.com/en-US/home']
# ['http://en.wikinews.org/wiki/Controversy_raised_about_2009_Nobel_Prize_in_Physics']
# ['None']
# ['happy', 'birthdayy', ':)']
# ['happy', 'b&#039;day!!!']
# ['happy', 'b&#039;day', 'mama...']
# ['happy', 'birthday', 'man..!!']
# ['Happy', 'Birthday.....:):)']
# ['Happy', 'B&#039;Day', 'dude...............']
# ['Happy', 'Birthday', 'Rahul!']
# ['HAPPY', 'BIRTHDAY!']
# ['Happy', 'Birthday', 'Doodh!!!']
# ['Happy', 'birthday', 'dude!']
# ['happy', 'bday!!!!']
# ['Happy', 'Birthday', 'dude!']
# ['happy', 'birthday', 'ra']
# ['happy', 'birthday', 'ra']
# ['happy', 'bthday...']
# ['happy', 'birthday', 'ra']
# ['happy', 'birthday', 'mama...']
# ['None']
# ['None']
# ['lol', '....']
# ['www.shaastra.org', ',,,,,']
# ['http://www.thefuntheory.com/', '-', 'awesomeeeee......']
# ['thnx', 'dude...:D']
# [':P']
# ['hii', '!!!!']
# ['hi', 'where', 'r']
# ['grrr.....']
# ['happy', 'b&#039;day', 'da.......']
# ['happy', 'birthday!!']
# ['Happy', 'b&#039;day', 'bro...!!!!']
# ['School', 'rahul', '!']
# ['what&#039;s', 'cookin', '?']
# ['None']
# ['None']

# %%
dayListDict = dict((x, dayList.count(x)) for x in dayList)
dateListDict = dict((x, dateList.count(x)) for x in dateList)
monthListDict = dict((x, monthList.count(x)) for x in monthList)
yearListDict = dict((x, yearList.count(x)) for x in yearList)

# %%
print dayListDict['Monday,'], dayListDict['Tuesday,'], dayListDict['Wednesday,']
print dayListDict['Thursday,'], dayListDict['Friday,'], dayListDict['Saturday,'], dayListDict['Sunday,']
# Out:
# 347 348 361
# 297 339 278 397

# %%
print monthListDict['January'], monthListDict['February'], monthListDict['March'], monthListDict['April']
print monthListDict['May'], monthListDict['June'], monthListDict['July'], monthListDict['August']
print monthListDict['September'], monthListDict['October'], monthListDict['November'], monthListDict['December']
# Out:
#  122 422 183 115
# 166 219 183 144
# 247 220 115 231

# %%
print yearListDict['2009'], yearListDict['2010'], yearListDict['2011'], yearListDict['2012']
print yearListDict['2013'], yearListDict['2014'], yearListDict['2015']
# Out:
#  51 225 474 495
# 661 252 204

# %%
dates[3:10]
# Out:
# [['Monday,', 'January', '11,', '2016', 'at', '1:13am', 'UTC+05:30'],
#  ['Sunday,', 'January', '10,', '2016', 'at', '6:32pm', 'UTC+05:30'],
#  ['Sunday,', 'January', '10,', '2016', 'at', '5:53pm', 'UTC+05:30'],
#  ['Saturday,', 'January', '9,', '2016', 'at', '5:24pm', 'UTC+05:30'],
#  ['Aaahahahahaha', 'omg', 'this', 'is', 'amazing!', ':D'],
#  ['Friday,', 'January', '1,', '2016', 'at', '9:51pm', 'UTC+05:30'],
#  ['Thursday,', 'December', '31,', '2015', 'at', '7:40pm', 'UTC+05:30']]

# %%
plt.hist(dayList, bins=7)
plt.show()

# %%
print list(set(dayList))
print list(set([string[1] for string in dates[3:]]))
print list(set([string[2] for string in dates[3:]]))
print list(set([string[3] for string in dates[3:]]))
